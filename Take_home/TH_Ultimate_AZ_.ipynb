# %% [markdown]
# ## Ultimate Inc. Challenge

# %% [markdown]
# ### Part 1 - Exploratory Data Analysis

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Open and read the JSON file
with open('logins.json', 'r') as file:
    data = json.load(file)

data
# Out:
# {'login_time': ['1970-01-01 20:13:18',
#   '1970-01-01 20:16:10',
#   '1970-01-01 20:16:37',
#   '1970-01-01 20:16:36',
#   '1970-01-01 20:26:21',
#   '1970-01-01 20:21:41',
#   '1970-01-01 20:12:16',
#   '1970-01-01 20:35:47',
#   '1970-01-01 20:35:38',
#   '1970-01-01 20:47:52',
#   '1970-01-01 20:26:05',
#   '1970-01-01 20:31:03',
#   '1970-01-01 20:34:46',
#   '1970-01-01 20:36:34',
#   '1970-01-01 20:39:25',
#   '1970-01-01 20:40:37',
#   '1970-01-01 20:34:58',
#   '1970-01-01 20:43:59',
#   '1970-01-01 20:47:46',
#   '1970-01-01 20:46:34',
#   '1970-01-01 20:56:07',
#   '1970-01-01 20:49:12',
#   '1970-01-01 20:59:06',
#   '1970-01-01 20:59:59',
#   '1970-01-01 21:15:01',
#   '1970-01-01 21:09:24',
#   '1970-01-01 21:19:24',
#   '1970-01-01 21:20:53',
#   '1970-01-01 21:29:19',
#   '1970-01-01 21:58:05',
#   '1970-01-01 21:51:51',
#   '1970-01-01 21:59:40',
#   '1970-01-01 22:08:34',
#   '1970-01-01 22:02:51',
#   '1970-01-01 21:58:32',
#   '1970-01-01 22:02:31',
# ...

# %%
# Inspecting the data
num_keys= len(data.keys())
num_values = len(data.values())
print (num_keys, num_values)
# Out:
# 1 1

# %%
# Getting the values by calling the key
data['login_time']
# Out:
# ['1970-01-01 20:13:18',
#  '1970-01-01 20:16:10',
#  '1970-01-01 20:16:37',
#  '1970-01-01 20:16:36',
#  '1970-01-01 20:26:21',
#  '1970-01-01 20:21:41',
#  '1970-01-01 20:12:16',
#  '1970-01-01 20:35:47',
#  '1970-01-01 20:35:38',
#  '1970-01-01 20:47:52',
#  '1970-01-01 20:26:05',
#  '1970-01-01 20:31:03',
#  '1970-01-01 20:34:46',
#  '1970-01-01 20:36:34',
#  '1970-01-01 20:39:25',
#  '1970-01-01 20:40:37',
#  '1970-01-01 20:34:58',
#  '1970-01-01 20:43:59',
#  '1970-01-01 20:47:46',
#  '1970-01-01 20:46:34',
#  '1970-01-01 20:56:07',
#  '1970-01-01 20:49:12',
#  '1970-01-01 20:59:06',
#  '1970-01-01 20:59:59',
#  '1970-01-01 21:15:01',
#  '1970-01-01 21:09:24',
#  '1970-01-01 21:19:24',
#  '1970-01-01 21:20:53',
#  '1970-01-01 21:29:19',
#  '1970-01-01 21:58:05',
#  '1970-01-01 21:51:51',
#  '1970-01-01 21:59:40',
#  '1970-01-01 22:08:34',
#  '1970-01-01 22:02:51',
#  '1970-01-01 21:58:32',
#  '1970-01-01 22:02:31',
#  '1970-01-01 22:05:32',
#  '1970-01-01 22:02:46',
# ...

# %%
# Length of the values
len(data['login_time'])
# Out:
# 93142

# %% [markdown]
# There are 93142 login entries available in the dictionary

# %%
# Create a dataframe
df = pd.DataFrame(data['login_time'], columns=['login_time'], index=None)
df.head()
# Out:
#             login_time
# 0  1970-01-01 20:13:18
# 1  1970-01-01 20:16:10
# 2  1970-01-01 20:16:37
# 3  1970-01-01 20:16:36
# 4  1970-01-01 20:26:21

# %%
# Exploring the data
#print (df.info(), df.describe(), df.shape, df.dtypes, df.isnull().sum(), df.duplicated().sum())
print (df.info())
print(df.describe())
print (df.shape) 
print(df.dtypes)
print (df.isnull().sum())
print (df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   login_time  93142 non-null  object
# dtypes: object(1)
# memory usage: 727.8+ KB
# None
#                  login_time
# count                 93142
# unique                92265
# top     1970-03-17 01:01:39
# freq                      3
# (93142, 1)
# login_time    object
# dtype: object
# login_time    0
# dtype: int64
# 877

# %%
# convert to numeric
df['login_time'] = pd.to_datetime(df['login_time'])

# %%
df.isna().sum()
# Out:
# login_time    0
# dtype: int64

# %%
# Exploratory data analysis
df.describe()
# Out:
# C:\Users\aubhi\AppData\Local\Temp/ipykernel_23160/3184240622.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                  login_time
# count                 93142
# unique                92265
# top     1970-03-17 01:01:39
# freq                      3
# first   1970-01-01 20:12:16
# last    1970-04-13 18:57:38

# %%
# Plotting the data as a histogram
df.plot.hist(bins=50, figsize=(10,5))
# Set x-axis start and end values
#plt.xlim(pd.Timestamp('1970-01-01 00:00:00'), pd.Timestamp('1970-04-13 23:59:59'))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Copying the dataframe
df_1 = df.copy()
# Grouping the data by 15 minute intervals
df_1.set_index('login_time', inplace=True)
df_1['count'] = 1
df_15T = df_1.resample('15T').sum()
df_15T.head()
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1

# %%
# Plotting the data
df_15T.plot(figsize=(10,5))
plt.ylabel('Number of logins')
plt.legend(loc='upper left')
# Overlap distribution
#df_15T.plot(kind= 'violin',figsize=(10,5), color='red', alpha=0.6)

# %%
# Plotting histogram
plt.figure(figsize=(10,5))

plt.subplot (1,2,1)
# histogram
plt.hist(df_15T['count'], bins=50)

plt.subplot (1,2,2)
sns.kdeplot(df_15T['count'], shade=True, color='r')

plt. tight_layout()
plt.show()

# %%
# Exploring the df_15T dataframe
df_15T.describe()
# Out:
#              count
# count  9788.000000
# mean      9.515938
# std       8.328818
# min       0.000000
# 25%       3.000000
# 50%       7.000000
# 75%      13.000000
# max      73.000000

# %%
df_15T.median()
# Out:
# count    7.0
# dtype: float64

# %% [markdown]
# Average number of logins per 15 mins is 9.5 (~10). The median count is 7. Also it appears there may be a bit of a seasonality in the dataset. We could do some time series analysis to identify the seasonality

# %%
# Copying the dataframe
df_2 = df.copy()
# Grouping the data by 1day intervals
df_2.set_index('login_time', inplace=True)
df_2['count'] = 1
df_1d = df_1.resample('1D').sum()
df_1d.head()
# Out:
#             count
# login_time
# 1970-01-01    112
# 1970-01-02    681
# 1970-01-03    793
# 1970-01-04    788
# 1970-01-05    459

# %%
# Describe the data
df_1d.describe()
# Out:
#              count
# count   103.000000
# mean    904.291262
# std     347.167463
# min     112.000000
# 25%     643.000000
# 50%     827.000000
# 75%    1141.000000
# max    1889.000000

# %%
# Use pandas profiling explore the data
import pandas_profiling
df_1d.profile_report()
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# Per day on avearge 905 logins occur

# %%
# Plotting the data
df_1d.plot(figsize=(10,5))
plt.ylabel('Number of logins')
plt.legend(loc='upper left')

# %%
# importing decompose
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# Plot the original data, the trend, the seasonality, and the residuals 
decomposition = seasonal_decompose(df_1d['count'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
y = df_1d['count']
# Plotting the trend and seasonality
plt.figure(figsize=(10,5))

plt.subplot(2,2,1)
plt.plot(y, label='Original')
plt.legend(loc='best')
plt.xticks(rotation=45)

plt.subplot(2,2,2)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.xticks(rotation=45)

plt.subplot(2,2,3)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.xticks(rotation=45)

plt.subplot(2,2,4)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Which day of the week is the spike in the data?
df_1d['day_of_week'] = df_1d.index.dayofweek
df_1d.head()
# Out:
#             count  day_of_week
# login_time
# 1970-01-01    112            3
# 1970-01-02    681            4
# 1970-01-03    793            5
# 1970-01-04    788            6
# 1970-01-05    459            0

# %%
# Copying the dataframe
df_3 = df_1d.copy()
# Groupby day of the week count
df_3.groupby('day_of_week')['count'].sum().sort_values(ascending=False)
# Out:
# day_of_week
# 5    19377
# 6    18167
# 4    15208
# 3    11960
# 2    10339
# 1     9268
# 0     8823
# Name: count, dtype: int64

# %% [markdown]
# Saturday (followed by Sundays) are most popular login times. This analysis can further be looked for morning vs afternoon pattern. For simplicity moving on.

# %%
# Which day of the month is the spike in the data?
df_1d['day_of_month'] = df_1d.index.day
df_1d.head()
# Out:
#             count  day_of_week  day_of_month
# login_time
# 1970-01-01    112            3             1
# 1970-01-02    681            4             2
# 1970-01-03    793            5             3
# 1970-01-04    788            6             4
# 1970-01-05    459            0             5

# %%
# Copying the dataframe
df_4 = df_1d.copy()
# Groupby day of the week count
df_4.groupby('day_of_month')['count'].sum().sort_values(ascending=False)
# Out:
# day_of_month
# 4     4037
# 8     4019
# 7     4006
# 11    3863
# 12    3614
# 28    3540
# 22    3507
# 21    3487
# 3     3475
# 14    3426
# 15    3331
# 10    3297
# 6     3281
# 5     3223
# 1     3194
# 2     3044
# 17    3044
# 13    3021
# 18    2945
# 20    2885
# 19    2859
# 9     2832
# 27    2735
# 25    2348
# 24    2318
# 23    2233
# 16    2215
# 29    2197
# 26    2176
# 31    1575
# 30    1415
# Name: count, dtype: int64

# %% [markdown]
# Interestingly 4th, 7th and 8th of the month came out to have the most logins. Not 1st. No obvious pattern. But this is probably due to weekends

# %%
# Which month is the spike in the data?
df_1d['month'] = df_1d.index.month
df_1d.head()
# Out:
#             count  day_of_week  day_of_month  month
# login_time
# 1970-01-01    112            3             1      1
# 1970-01-02    681            4             2      1
# 1970-01-03    793            5             3      1
# 1970-01-04    788            6             4      1
# 1970-01-05    459            0             5      1

# %%
# Copying the dataframe
df_5 = df_1d.copy()
# Groupby month count
df_5.groupby('month')['count'].sum().sort_values(ascending=False)
# Out:
# month
# 3    33723
# 2    24673
# 1    21239
# 4    13507
# Name: count, dtype: int64

# %%
df_6= df_5.groupby('month')['count'].sum().sort_values(ascending=False)
# drop the month 4
df_6.drop(4, inplace=True)
#Plot the data as a line plot
df_6.plot(kind='line', figsize=(10,5))y
# Out:
# <AxesSubplot:xlabel='month'>

# %%
# Now again generate the profile report
df_1d.profile_report()
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ## Part 3 - Predictive modeling

# %%
#import data from json file
with open('ultimate_data_challenge.json') as f:
    data = json.loads(f.read())
df = pd.DataFrame(data)
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %%
#Describe and inspect the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    50000 non-null  object
#  1   trips_in_first_30_days  50000 non-null  int64
#  2   signup_date             50000 non-null  object
#  3   avg_rating_of_driver    41878 non-null  float64
#  4   avg_surge               50000 non-null  float64
#  5   last_trip_date          50000 non-null  object
#  6   phone                   49604 non-null  object
#  7   surge_pct               50000 non-null  float64
#  8   ultimate_black_user     50000 non-null  bool
#  9   weekday_pct             50000 non-null  float64
#  10  avg_dist                50000 non-null  float64
#  11  avg_rating_by_driver    49799 non-null  float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %%
#Describe
df.describe()
# Out:
#        trips_in_first_30_days  avg_rating_of_driver     avg_surge  \
# count            50000.000000          41878.000000  50000.000000
# mean                 2.278200              4.601559      1.074764
# std                  3.792684              0.617338      0.222336
# min                  0.000000              1.000000      1.000000
# 25%                  0.000000              4.300000      1.000000
# 50%                  1.000000              4.900000      1.000000
# 75%                  3.000000              5.000000      1.050000
# max                125.000000              5.000000      8.000000
#
#           surge_pct   weekday_pct      avg_dist  avg_rating_by_driver
# count  50000.000000  50000.000000  50000.000000          49799.000000
# mean       8.849536     60.926084      5.796827              4.778158
# std       19.958811     37.081503      5.707357              0.446652
# min        0.000000      0.000000      0.000000              1.000000
# ...

# %%
# missing values
df.isna().sum()
# Out:
# city                         0
# trips_in_first_30_days       0
# signup_date                  0
# avg_rating_of_driver      8122
# avg_surge                    0
# last_trip_date               0
# phone                      396
# surge_pct                    0
# ultimate_black_user          0
# weekday_pct                  0
# avg_dist                     0
# avg_rating_by_driver       201
# dtype: int64

# %%
df.isnull().sum()
# Out:
# city                         0
# trips_in_first_30_days       0
# signup_date                  0
# avg_rating_of_driver      8122
# avg_surge                    0
# last_trip_date               0
# phone                      396
# surge_pct                    0
# ultimate_black_user          0
# weekday_pct                  0
# avg_dist                     0
# avg_rating_by_driver       201
# dtype: int64

# %% [markdown]
# Average rating by drivers are missing. I will fill this up with median value

# %%
df.duplicated().sum()
# Out:
# 8

# %% [markdown]
# 8 rows are duplicated exactly and should be taken away

# %%
# Checking unique values in each column
df.nunique()
# Out:
# city                         3
# trips_in_first_30_days      59
# signup_date                 31
# avg_rating_of_driver        37
# avg_surge                  115
# last_trip_date             182
# phone                        2
# surge_pct                  367
# ultimate_black_user          2
# weekday_pct                666
# avg_dist                  2908
# avg_rating_by_driver        27
# dtype: int64

# %%
df.shape
# Out:
# (50000, 12)

# %%
# Copy the dataframe
df_num = df.copy()
# Fill in missing value for driver rating
df_num['avg_rating_of_driver'].fillna(df_num['avg_rating_of_driver'].mean(), inplace=True)
df_num.head(10)
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25              4.700000
# 1         Astapor                       0  2014-01-29              5.000000
# 2         Astapor                       3  2014-01-06              4.300000
# 3  King's Landing                       9  2014-01-10              4.600000
# 4      Winterfell                      14  2014-01-27              4.400000
# 5      Winterfell                       2  2014-01-09              3.500000
# 6         Astapor                       1  2014-01-24              4.601559
# 7      Winterfell                       2  2014-01-28              5.000000
# 8      Winterfell                       2  2014-01-21              4.500000
# 9      Winterfell                       1  2014-01-03              4.601559
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# ...

# %%
df_num['avg_rating_of_driver'].mean()
# Out:
# 4.601559291274253

# %%
df_num['avg_rating_by_driver'].mean()
# Out:
# 4.778158195947439

# %%
df_num.isnull().sum()
# Out:
# city                        0
# trips_in_first_30_days      0
# signup_date                 0
# avg_rating_of_driver        0
# avg_surge                   0
# last_trip_date              0
# phone                     396
# surge_pct                   0
# ultimate_black_user         0
# weekday_pct                 0
# avg_dist                    0
# avg_rating_by_driver      201
# dtype: int64

# %% [markdown]
# Why did the fillna not work??

# %%
# Drop telephone column
df_num.drop('phone', axis=1, inplace=True)
df_num.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date  surge_pct  ultimate_black_user  weekday_pct  \
# 0       1.10     2014-06-17       15.4                 True         46.2
# 1       1.00     2014-05-05        0.0                False         50.0
# 2       1.00     2014-01-07        0.0                False        100.0
# 3       1.14     2014-06-29       20.0                 True         80.0
# 4       1.19     2014-03-15       11.8                False         82.4
#
#    avg_dist  avg_rating_by_driver
# 0      3.67                   5.0
# ...

# %%
df_num['avg_rating_by_driver']= df_num['avg_rating_by_driver'].fillna(value=4.8)
df_num.head(10)
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25              4.700000
# 1         Astapor                       0  2014-01-29              5.000000
# 2         Astapor                       3  2014-01-06              4.300000
# 3  King's Landing                       9  2014-01-10              4.600000
# 4      Winterfell                      14  2014-01-27              4.400000
# 5      Winterfell                       2  2014-01-09              3.500000
# 6         Astapor                       1  2014-01-24              4.601559
# 7      Winterfell                       2  2014-01-28              5.000000
# 8      Winterfell                       2  2014-01-21              4.500000
# 9      Winterfell                       1  2014-01-03              4.601559
#
#    avg_surge last_trip_date  surge_pct  ultimate_black_user  weekday_pct  \
# ...

# %%
df_num.isna().sum()
# Out:
# city                      0
# trips_in_first_30_days    0
# signup_date               0
# avg_rating_of_driver      0
# avg_surge                 0
# last_trip_date            0
# surge_pct                 0
# ultimate_black_user       0
# weekday_pct               0
# avg_dist                  0
# avg_rating_by_driver      0
# dtype: int64

# %%
#Export the dataframe as a csv file
df_num.to_csv('ultimate_data_challenge.csv', index=False)

# %% [markdown]
# ### EDA analysis

# %% [markdown]
# Active users= last 30 day users. Calculatng last trip date as the last date for this analysis

# %%
#convert to timestamp
df_num['last_trip_date'] = pd.to_datetime(df['last_trip_date'])
df_num['signup_date'] = pd.to_datetime(df['signup_date'])
df_num.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date  surge_pct  ultimate_black_user  weekday_pct  \
# 0       1.10     2014-06-17       15.4                 True         46.2
# 1       1.00     2014-05-05        0.0                False         50.0
# 2       1.00     2014-01-07        0.0                False        100.0
# 3       1.14     2014-06-29       20.0                 True         80.0
# 4       1.19     2014-03-15       11.8                False         82.4
#
#    avg_dist  avg_rating_by_driver
# 0      3.67                   5.0
# ...

# %%
#Last date for analysis
last_date = df['last_trip_date'].max()
last_date
# Out:
# '2014-07-01'

# %%
# Convert last date to datetime
last_date = pd.to_datetime(last_date)
last_date
# Out:
# Timestamp('2014-07-01 00:00:00')

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    50000 non-null  object
#  1   trips_in_first_30_days  50000 non-null  int64
#  2   signup_date             50000 non-null  datetime64[ns]
#  3   avg_rating_of_driver    50000 non-null  float64
#  4   avg_surge               50000 non-null  float64
#  5   last_trip_date          50000 non-null  datetime64[ns]
#  6   surge_pct               50000 non-null  float64
#  7   ultimate_black_user     50000 non-null  bool
#  8   weekday_pct             50000 non-null  float64
#  9   avg_dist                50000 non-null  float64
#  10  avg_rating_by_driver    50000 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(1), object(1)
# memory usage: 3.9+ MB

# %%
#Classifying active vs inactive customers
df_num['active'] = df_num['last_trip_date'].apply(lambda x: 0 if (last_date-x).days >30 else 1)
df_num.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date  surge_pct  ultimate_black_user  weekday_pct  \
# 0       1.10     2014-06-17       15.4                 True         46.2
# 1       1.00     2014-05-05        0.0                False         50.0
# 2       1.00     2014-01-07        0.0                False        100.0
# 3       1.14     2014-06-29       20.0                 True         80.0
# 4       1.19     2014-03-15       11.8                False         82.4
#
#    avg_dist  avg_rating_by_driver  active
# ...

# %%
# How many active and inactive
df_num['active'].value_counts(normalize=True)
# Out:
# 0    0.62392
# 1    0.37608
# Name: active, dtype: float64

# %% [markdown]
# ### A little more than one third of the customers are active.

# %%
# Catagorical and non catagorical columns
cat_cols = ['city', 'ultimate_black_user']
df_num_2= pd.get_dummies(df_num, columns=cat_cols)
df_num_2.head()
# Out:
#    trips_in_first_30_days signup_date  avg_rating_of_driver  avg_surge  \
# 0                       4  2014-01-25                   4.7       1.10
# 1                       0  2014-01-29                   5.0       1.00
# 2                       3  2014-01-06                   4.3       1.00
# 3                       9  2014-01-10                   4.6       1.14
# 4                      14  2014-01-27                   4.4       1.19
#
#   last_trip_date  surge_pct  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0     2014-06-17       15.4         46.2      3.67                   5.0
# 1     2014-05-05        0.0         50.0      8.26                   5.0
# 2     2014-01-07        0.0        100.0      0.77                   5.0
# 3     2014-06-29       20.0         80.0      2.36                   4.9
# 4     2014-03-15       11.8         82.4      3.13                   4.9
#
#    active  city_Astapor  city_King's Landing  city_Winterfell  \
# ...

# %%
#target feature
y = df_num_2['active']

# %%
#kdeplot of active vs inactive
sns.kdeplot(y)
# Out:
# <AxesSubplot:xlabel='active', ylabel='Density'>

# %%
# pairplot
sns.pairplot(df_num_2)

# %% [markdown]
# ### Good to see not any colinearity. Moving ahead

# %%
# Correlation matrix
df_num_2.corr()
# Out:
#                            trips_in_first_30_days  avg_rating_of_driver  \
# trips_in_first_30_days                   1.000000             -0.011060
# avg_rating_of_driver                    -0.011060              1.000000
# avg_surge                               -0.001841             -0.021653
# surge_pct                                0.005720             -0.003290
# weekday_pct                              0.050388              0.012587
# avg_dist                                -0.136329              0.028508
# avg_rating_by_driver                    -0.039187              0.101642
# active                                   0.210463             -0.010829
# city_Astapor                            -0.061075              0.029814
# city_King's Landing                      0.024650              0.082156
# city_Winterfell                          0.037735             -0.094304
# ultimate_black_user_False               -0.112210              0.001916
# ...

# %%
# Heatmap
sns.heatmap(df_num_2.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
cols= df_num_2.columns
cols
# Out:
# Index(['trips_in_first_30_days', 'signup_date', 'avg_rating_of_driver',
#        'avg_surge', 'last_trip_date', 'surge_pct', 'weekday_pct', 'avg_dist',
#        'avg_rating_by_driver', 'active', 'city_Astapor', 'city_King's Landing',
#        'city_Winterfell', 'ultimate_black_user_False',
#        'ultimate_black_user_True'],
#       dtype='object')

# %%
#violinplot and a distribution plot
for i in cols:
    sns.violinplot(data= df_num_2, x='active',y=i)

# %% [markdown]
# ### Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
df_num_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   trips_in_first_30_days     50000 non-null  int64
#  1   signup_date                50000 non-null  datetime64[ns]
#  2   avg_rating_of_driver       50000 non-null  float64
#  3   avg_surge                  50000 non-null  float64
#  4   last_trip_date             50000 non-null  datetime64[ns]
#  5   surge_pct                  50000 non-null  float64
#  6   weekday_pct                50000 non-null  float64
#  7   avg_dist                   50000 non-null  float64
#  8   avg_rating_by_driver       50000 non-null  float64
#  9   active                     50000 non-null  int64
#  10  city_Astapor               50000 non-null  uint8
#  11  city_King's Landing        50000 non-null  uint8
#  12  city_Winterfell            50000 non-null  uint8
# ...

# %%
df_num_3= df_num_2.copy()

# %%
# Change name of column city_King's Landing to city_Kings_Landing
df_num_3.rename(columns={'city_King\'s Landing':'city_Kings_Landing'}, inplace=True)

# %%
df_num_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   trips_in_first_30_days     50000 non-null  int64
#  1   signup_date                50000 non-null  datetime64[ns]
#  2   avg_rating_of_driver       50000 non-null  float64
#  3   avg_surge                  50000 non-null  float64
#  4   last_trip_date             50000 non-null  datetime64[ns]
#  5   surge_pct                  50000 non-null  float64
#  6   weekday_pct                50000 non-null  float64
#  7   avg_dist                   50000 non-null  float64
#  8   avg_rating_by_driver       50000 non-null  float64
#  9   active                     50000 non-null  int64
#  10  city_Astapor               50000 non-null  uint8
#  11  city_Kings_Landing         50000 non-null  uint8
#  12  city_Winterfell            50000 non-null  uint8
# ...

# %%
# Converting unit8 columns to int64
df_num_3['city_Astapor'] = df_num_3['city_Astapor'].astype(int)
df_num_3['city_Kings_Landing'] = df_num_3['city_Kings_Landing'].astype(int)
df_num_3['city_Winterfell'] = df_num_3['city_Winterfell'].astype(int)
df_num_3['ultimate_black_user_False'] = df_num_3['ultimate_black_user_False'].astype(int)
df_num_3['ultimate_black_user_True'] = df_num_3['ultimate_black_user_True'].astype(int)

# %%
df_num_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   trips_in_first_30_days     50000 non-null  int64
#  1   signup_date                50000 non-null  datetime64[ns]
#  2   avg_rating_of_driver       50000 non-null  float64
#  3   avg_surge                  50000 non-null  float64
#  4   last_trip_date             50000 non-null  datetime64[ns]
#  5   surge_pct                  50000 non-null  float64
#  6   weekday_pct                50000 non-null  float64
#  7   avg_dist                   50000 non-null  float64
#  8   avg_rating_by_driver       50000 non-null  float64
#  9   active                     50000 non-null  int64
#  10  city_Astapor               50000 non-null  int32
#  11  city_Kings_Landing         50000 non-null  int32
#  12  city_Winterfell            50000 non-null  int32
# ...

# %%
features= df_num_3.drop(['active', 'last_trip_date', 'signup_date'], axis=1)

# %%
#Our data is a binary classification and henc need to use a quantile scaling
scaler = QuantileTransformer()
scaled_features = scaler.fit_transform(features)

# %%
#split data for training and testing
X_train, X_test, y_train, y_test = train_test_split(scaled_features, y, test_size=0.2,random_state=42)

# %%
#Trying Random forest first
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

# %%
rf.score(X_test,y_test)
# Out:
# 0.7383

# %%
# Cross validation
rf_cv = cross_val_score(rf, X_train, y_train, cv=5)
rf_cv
# Out:
# array([0.7435  , 0.74675 , 0.747375, 0.7505  , 0.745375])

# %%
# Mean of cross validation
np.mean(rf_cv)
# Out:
# 0.7467

# %% [markdown]
# ### Now trying logistic regression

# %%
# Trying logistic regression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# Logistic regression score
logreg.score(X_test,y_test)
# Out:
# 0.7359

# %%
# Cross validation
logreg_cv = cross_val_score(logreg, X_train, y_train, cv=5)

# %%
# Mean of cross validation
np.mean(logreg_cv)
# Out:
# 0.73835

# %% [markdown]
# ### Trying Decision tree

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Score of decision tree
dt.score(X_test,y_test)
# Out:
# 0.6955

# %%
#cross validation
dt_cv = cross_val_score(dt, X_train, y_train, cv=5)

# %%
# Mean of cross validation
np.mean(dt_cv)
# Out:
# 0.7006

# %% [markdown]
# ### Trying gradient boosting

# %%
# Gradient boosting classifier
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Score of gradient boosting classifier
gb.score(X_test,y_test)
# Out:
# 0.7757

# %%
#Cross validation
gb_cv = cross_val_score(gb, X_train, y_train, cv=5)

# %%
#Mean of cross validation
np.mean(gb_cv)
# Out:
# 0.7752249999999999

# %% [markdown]
# #### Best classifier so far has been the gradient boosting and random forest

# %%
# Confusion matrix for gradient boosting classifier
gb_pred = gb.predict(X_test)
gb_confusion = confusion_matrix(y_test, gb_pred)
#convert to percentage
gb_confusion = gb_confusion.astype('float') / gb_confusion.sum(axis=1)[:, np.newaxis]
sns.heatmap(gb_confusion, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#Precision recall and f score on RF
precision_recall_fscore_support(y_test,y_pred)
# Out:
# (array([0.78992273, 0.65364308]),
#  array([0.78903361, 0.65485321]),
#  array([0.78947792, 0.65424759]),
#  array([6219, 3781], dtype=int64))

# %%
#Precision recall and f score on GB
precision_recall_fscore_support(y_test,gb_pred)
# Out:
# (array([0.79814037, 0.73079232]),
#  array([0.85576459, 0.64400952]),
#  array([0.82594863, 0.68466189]),
#  array([6219, 3781], dtype=int64))

# %% [markdown]
# #### Since the dataset is imbalanced; we want to apply weighted metrics

# %%
#weighted metrics for RF
precision_recall_fscore_support(y_test,y_pred,average='weighted')
# Out:
# (0.7383953957527447, 0.7383, 0.7383473306152405, None)

# %%
#weighted metrics for GB
precision_recall_fscore_support(y_test,gb_pred,average='weighted')
# Out:
# (0.7726760723305519, 0.7757, 0.7725281126035672, None)

# %% [markdown]
# #### Can we try hyperparameter tuning for GB?

# %%
# Initialize the model
param_grid = {
    'n_estimators': [50, 100, 150],  # Number of boosting stages to be run
    'learning_rate': [0.1, 0.05, 0.01],  # Step size shrinkage used in updating weights
    'max_depth': [3, 5, 7],  # Maximum depth of the individual trees
}

gb_classifier = GradientBoostingClassifier(random_state=42)
# Create a GridSearchCV instance
grid_search = GridSearchCV(estimator=gb_classifier, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV to find the best hyperparameters
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and their corresponding performance score
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy Score:", grid_search.best_score_)

# Evaluate the model with the best hyperparameters on the test set
best_gb_classifier = grid_search.best_estimator_
test_accuracy = best_gb_classifier.score(X_test, y_test)
print("Test Accuracy with Best Hyperparameters:", test_accuracy)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# Best Accuracy Score: 0.779625
# Test Accuracy with Best Hyperparameters: 0.7802

# %%
logreg_classifier = LogisticRegression(random_state=42)

# Define hyperparameters and their respective values to be tuned
param_grid = {
    'C': [0.1, 1, 10],  # Inverse of regularization strength (smaller values specify stronger regularization)
    'penalty': ['l1', 'l2'],  # Regularization term ('l1': Lasso, 'l2': Ridge)
}

# Create a GridSearchCV instance
grid_search = GridSearchCV(estimator=logreg_classifier, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV to find the best hyperparameters
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and their corresponding performance score
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy Score:", grid_search.best_score_)

# Evaluate the model with the best hyperparameters on the test set
best_logreg_classifier = grid_search.best_estimator_
test_accuracy = best_logreg_classifier.score(X_test, y_test)
print("Test Accuracy with Best Hyperparameters:", test_accuracy)
# Out:
# Best Hyperparameters: {'C': 0.1, 'penalty': 'l2'}
# Best Accuracy Score: 0.7385750000000002
# Test Accuracy with Best Hyperparameters: 0.7358

# %%
rf_classifier = RandomForestClassifier(random_state=42)

# Define hyperparameters and their respective values to be tuned
param_grid = {
    'n_estimators': [50, 100, 150],  # Number of trees in the forest
    'max_depth': [None, 5, 10],  # Maximum depth of the individual trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
}

# Create a GridSearchCV instance
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV to find the best hyperparameters
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and their corresponding performance score
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Accuracy Score:", grid_search.best_score_)

# Evaluate the model with the best hyperparameters on the test set
best_rf_classifier = grid_search.best_estimator_
test_accuracy = best_rf_classifier.score(X_test, y_test)
print("Test Accuracy with Best Hyperparameters:", test_accuracy)
# Out:
# Best Hyperparameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50}
# Best Accuracy Score: 0.7756
# Test Accuracy with Best Hyperparameters: 0.7734

# %% [markdown]
# Best model is the gradient boost algorithm with learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100. The accuracy of the model is ~80%

# %%
#find coefficients from gradient boosting classifier
gb_coef = GradientBoostingClassifier(learning_rate=0.1, max_depth= 5, n_estimators=100)
gb_coef.fit(X_train,y_train)
gb_coef.score(X_test,y_test)

# Cross validation
gb_coef_cv = cross_val_score(gb_coef, X_train, y_train, cv=5)

# Feature importance and coefficients as a dataframe
gb_coef.feature_importances_
gb_coef_df = pd.DataFrame(gb_coef.feature_importances_, index=features.columns, columns=['importance']).sort_values('importance', ascending=False)

# %%
gb_coef_cv.mean()
# Out:
# 0.77965

# %%
# Only coefficients of logistic regression for directional information
logit_coef = LogisticRegression(C=0.1, penalty='l2')
logit_coef.fit(X_train,y_train)
df_coef = pd.DataFrame(zip(list(features.columns),logit_coef.coef_[0]),index=range(features.columns.shape[0]),columns=['feature','coefficient']) # coef_[0] because it is a 2D array binary classification
df_coef
# Out:
#                       feature  coefficient
# 0      trips_in_first_30_days     0.114514
# 1        avg_rating_of_driver    -0.315672
# 2                   avg_surge     1.207607
# 3                   surge_pct    -0.057756
# 4                 weekday_pct    -0.223309
# 5                    avg_dist     0.147779
# 6        avg_rating_by_driver    -1.347672
# 7                city_Astapor    -0.797520
# 8          city_Kings_Landing     1.070112
# 9             city_Winterfell    -0.272355
# 10  ultimate_black_user_False    -0.469710
# 11   ultimate_black_user_True     0.469947

# %%
gb_coef_df
# Out:
#                            importance
# avg_rating_by_driver         0.311326
# city_Kings_Landing           0.160812
# surge_pct                    0.152032
# weekday_pct                  0.137425
# trips_in_first_30_days       0.059715
# ultimate_black_user_False    0.051922
# avg_dist                     0.036959
# city_Astapor                 0.029241
# avg_rating_of_driver         0.021600
# ultimate_black_user_True     0.019007
# avg_surge                    0.017596
# city_Winterfell              0.002365

# %% [markdown]
# Besr feature is the average rating by the driver. The model accuracy is around 80%. And the avegare rating by drivers seems to be the best predictor of customer retension. Negative correlators are average rating by driver and of drver. Positive correlators are avg_surge, trips in last 30 days and kings landing customers. Trips in first 30 days is has a low coefficient and hence can be targeted for improvement. It means that we could run promotions targeting riders that completed a purchase in first 30 days to assure retension. We could also promo on Kings landing more to attract new high purchasing customers
